# %%
from matplotlib import pyplot as plt 
day_x  =[18,19,20,21,22,23]
a_price_y=[20046,17100,20000,24744,30500,24722]
plt.plot(day_x,a_price_y,color='g',linestyle='--',marker='o',linewidth=3)
b_price_y=[20040,17200,25000,23420,29000,30000]
plt.plot(day_x,b_price_y,color='r',linestyle='--',marker='o',linewidth=3)
plt.legend(['company A','company B'])
plt.xlabel('Day')
plt.ylabel('Price')
plt.savefig('pic.png')

# %%
#plot styles
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
from matplotlib import pyplot as plt 
day_x  =[18,19,20,21,22,23]
a_price_y=[20046,17100,20000,24744,30500,24722]
b_price_y=[20040,17200,25000,23420,29000,30000]
plt.plot(day_x,b_price_y)
plt.plot(day_x,a_price_y)
plt.style.use('ggplot')

plt.legend(['company A','company B'])
plt.xlabel('Day')
plt.ylabel('Price')
plt.savefig('pic.png')

# %%
from matplotlib import pyplot as plt 
day_x  =[18,19,20,21,22,23]
a_price_y=[20046,17100,20000,24744,30500,24722]
b_price_y=[20040,17200,25000,23420,29000,30000]
plt.bar(day_x,b_price_y,width=0.2)     #plt.bar is used to plot bars
plt.bar(day_x,a_price_y,width=0.2,align='edge')
plt.style.use('ggplot')
plt.legend(['company A','company B'])
plt.xlabel('Day')
plt.ylabel('Price')
plt.savefig('pic.png')

# %%
import pandas as pd

# %%
d=pd.read_csv('E:/jettus.csv')
d.head()
# Out:
#    date  price
# 0     1      20
# 1     2      30
# 2     3      30
# 3     4      25
# 4     5      15

# %%
a = d['date']
b = d['price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-1be4180a90c7> in <module>
#       1 a = d['date']
# ----> 2 b = d['price']
#
# ...
